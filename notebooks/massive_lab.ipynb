# %%
from dotenv import load_dotenv
import os
from IPython.display import Markdown, display
from datetime import datetime
load_dotenv(override=True)
# Out:
# True

# %%
## API Massive est setup ##
massive_api_key = os.getenv("MASSIVE_API_KEY")
if not massive_api_key:
    print("MASSIVE_API_KEY is not set")

# %%
## Obtenir la valeur de fermeture d'APPL
from massive import RESTClient
client = RESTClient(massive_api_key)
client.get_previous_close_agg("AAPL")[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 ## Obtenir la valeur de fermeture d'APPL
# ----> 2 from massive import RESTClient
#       3 client = RESTClient(massive_api_key)
#       4 client.get_previous_close_agg("AAPL")[0]
#
# ModuleNotFoundError: No module named 'massive'
